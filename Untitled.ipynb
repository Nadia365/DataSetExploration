# %%
#Load libraries 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import scipy as sc 
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %%
#read dataset 
dat=pd.read_csv('nyc_taxi_trip_duration.csv')

# %%
#Explore dataset 
 #shape 
dat.shape
# Out:
# (729322, 11)

# %%
#First 5 instances with head()
dat.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id1080784          2  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1  id0889885          1  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2  id0857912          2  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3  id3744273          2  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4  id0232939          1  2016-02-17 06:42:23  2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude store_and_fwd_flag  trip_duration
# 0         40.771164                  N            400
# ...

# %%
#Last 5 instances with tail()
dat.tail()
# Out:
#                id  vendor_id      pickup_datetime     dropoff_datetime  \
# 729317  id3905982          2  2016-05-21 13:29:38  2016-05-21 13:34:34
# 729318  id0102861          1  2016-02-22 00:43:11  2016-02-22 00:48:26
# 729319  id0439699          1  2016-04-15 18:56:48  2016-04-15 19:08:01
# 729320  id2078912          1  2016-06-19 09:50:47  2016-06-19 09:58:14
# 729321  id1053441          2  2016-01-01 17:24:16  2016-01-01 17:44:40
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 729317                2        -73.965919        40.789780         -73.952637
# 729318                1        -73.996666        40.737434         -74.001320
# 729319                1        -73.997849        40.761696         -74.001488
# 729320                1        -74.006706        40.708244         -74.013550
# 729321                4        -74.003342        40.743839         -73.945847
#
#         dropoff_latitude store_and_fwd_flag  trip_duration
# ...

# %%
#data columns 
dat.columns
# Out:
# Index(['id', 'vendor_id', 'pickup_datetime', 'dropoff_datetime',
#        'passenger_count', 'pickup_longitude', 'pickup_latitude',
#        'dropoff_longitude', 'dropoff_latitude', 'store_and_fwd_flag',
#        'trip_duration'],
#       dtype='object')

# %%
#Identify Numeric variables 
num_var=[ 'passenger_count', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'trip_duration']

# %%
#Identify categorical variables 
cat_var=['store_and_fwd_flag','vendor_id' ]

# %%
#Identifying id variables 
id_var=['id']

# %%
#identifying datetime variables 
date_var=['pickup_datetime' ,'dropoff_datetime']

# %%
#dataset types 
dat.dtypes
# Out:
# id                     object
# vendor_id               int64
# pickup_datetime        object
# dropoff_datetime       object
# passenger_count         int64
# pickup_longitude      float64
# pickup_latitude       float64
# dropoff_longitude     float64
# dropoff_latitude      float64
# store_and_fwd_flag     object
# trip_duration           int64
# dtype: object

# %%
#Dataset statisticla description 
dat.describe()
# Out:
#            vendor_id  passenger_count  pickup_longitude  pickup_latitude  \
# count  729322.000000    729322.000000     729322.000000    729322.000000
# mean        1.535403         1.662055        -73.973513        40.750919
# std         0.498745         1.312446          0.069754         0.033594
# min         1.000000         0.000000       -121.933342        34.712234
# 25%         1.000000         1.000000        -73.991859        40.737335
# 50%         2.000000         1.000000        -73.981758        40.754070
# 75%         2.000000         2.000000        -73.967361        40.768314
# max         2.000000         9.000000        -65.897385        51.881084
#
#        dropoff_longitude  dropoff_latitude  trip_duration
# count      729322.000000     729322.000000   7.293220e+05
# mean          -73.973422         40.751775   9.522291e+02
# std             0.069588          0.036037   3.864626e+03
# min          -121.933304         32.181141   1.000000e+00
# ...

# %%
#Display numerical variables
dat[num_var]
# Out:
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                     1        -73.953918        40.778873         -73.963875
# 1                     2        -73.988312        40.731743         -73.994751
# 2                     2        -73.997314        40.721458         -73.948029
# 3                     6        -73.961670        40.759720         -73.956779
# 4                     1        -74.017120        40.708469         -73.988182
# ...                 ...               ...              ...                ...
# 729317                2        -73.965919        40.789780         -73.952637
# 729318                1        -73.996666        40.737434         -74.001320
# 729319                1        -73.997849        40.761696         -74.001488
# 729320                1        -74.006706        40.708244         -74.013550
# 729321                4        -74.003342        40.743839         -73.945847
#
# ...

# %%
# calculating points of mean, median and standard deviation 
def cal_fun(data, feat):
    mean = data[feat].mean()
    median = data[feat].median()
    stdev = data[feat].mean()- data[feat].std(), data[feat].mean()+data[feat].std() 
    skew = data[feat].skew()
    kurt = data[feat].kurtosis()

# checking
    return mean, median, stdev, skew,kurt

# %%
cal_fun(dat, num_var[0])[2]
# Out:
# (0.34960900473444134, 2.974500236451208)

# %%
#univariate Analysis Kdplots of numerical variables 
plt.figure(figsize = (7,3), dpi = 100)
sns.kdeplot(x=dat[num_var[0]],shade=True)
sns.scatterplot( cal_fun(dat, num_var[0])[0], [0.1], color='red', label='mean')
sns.scatterplot( cal_fun(dat, num_var[0])[1] , [0.1], color='green', label='median')
sns.lineplot(  cal_fun(dat, num_var[0])[2], [0.1,0.1], color='black', label='standard deviation')
plt.xlabel("passenger_count")
plt.ylabel('Density')
plt.title('std_dev = {}; kurtosis = {};\nskew = {}; \nmean = {}; median = {}'.format((round(cal_fun(dat, num_var[0])[2][0],2),round(cal_fun(dat, num_var[0])[2][1],2)),
                                                                                                   round(cal_fun(dat, num_var[0])[4],2),
                                                                                                   round(cal_fun(dat, num_var[0])[3],2),
                                                                                                
                                                                                                   round(cal_fun(dat, num_var[0])[0],2),
                                                                                                   round(cal_fun(dat, num_var[0])[1],2)))
plt.show()

# %% [markdown]
# * Median passenger number = 1
#
# * Most customers age between 0 to 3
#
# * Skewness +2.14 : very less likely to be biased
#
# * Kurtosis = 3.46; very less likely to have extreme/outlier values.

# %%
plt.figure(figsize = (7,3), dpi = 100)
sns.kdeplot(x=dat[num_var[1]],shade=True)
sns.scatterplot( cal_fun(dat, num_var[1])[0], [0], color='red', label='mean')
sns.scatterplot( cal_fun(dat, num_var[1])[1] , [0], color='green', label='median')
sns.lineplot( cal_fun(dat, num_var[1])[2], [0,0], color='black', label='standard deviation')
plt.xlabel(num_var[1])
plt.ylabel('Density')
plt.title('std_dev = {}; kurtosis = {};\nskew = {}; \nmean = {}; median = {}'.format((round(cal_fun(dat, num_var[1])[2][0],2),round(cal_fun(dat, num_var[1])[2][1],2)),
                                                                                                   round(cal_fun(dat, num_var[1])[4],2),
                                                                                                   round(cal_fun(dat, num_var[1])[3],2),
                                                                                                
                                                                                                   round(cal_fun(dat, num_var[1])[0],2),
                                                                                                   round(cal_fun(dat, num_var[1])[1],2)))
plt.show()

# %% [markdown]
# * Median pickup longtitude = -73.98
#
# * Most pickup longtitude range form -74 to - 73
#
# * Skewness -44.22 : very likely to be biased towards high values of longititude
#
# * Kurtosis = 30978; very likely to have extreme/outlier values.

# %%
plt.figure(figsize = (7,3), dpi = 100)
sns.kdeplot(x=dat[num_var[2]],shade=True)
sns.scatterplot( cal_fun(dat, num_var[2])[0], [0], color='red', label='mean')
sns.scatterplot( cal_fun(dat, num_var[2])[1] , [0], color='green', label='median')
sns.lineplot( cal_fun(dat, num_var[2])[2], [0,0], color='black', label='standard deviation')
plt.xlabel(num_var[2])
plt.ylabel('Density')
plt.title('std_dev = {}; kurtosis = {};\nskew = {}; \nmean = {}; median = {}'.format((round(cal_fun(dat, num_var[2])[2][0],2),round(cal_fun(dat, num_var[2])[2][1],2)),
                                                                                                   round(cal_fun(dat, num_var[2])[4],2),
                                                                                                   round(cal_fun(dat, num_var[2])[3],2),
                                                                                                
                                                                                                   round(cal_fun(dat, num_var[2])[0],2),
                                                                                                   round(cal_fun(dat, num_var[2])[1],2)))
plt.show()

# %% [markdown]
# * Median pickup latitude = 40.75
#
# * Most pickup latitude range form 40.72 to 40.78
#
# * Skewness 35.37 : very likely to be biased towards lower values of latitude
#
# * Kurtosis = 19348 ; very likely to have extreme/outlier values.

# %%
plt.figure(figsize = (7,3), dpi = 100)
sns.kdeplot(x=dat[num_var[3]],shade=True)
sns.scatterplot( cal_fun(dat, num_var[3])[0], [0], color='red', label='mean')
sns.scatterplot( cal_fun(dat, num_var[3])[1] , [0], color='green', label='median')
sns.lineplot( cal_fun(dat, num_var[3])[2], [0,0], color='black', label='standard deviation')
plt.xlabel(num_var[3])
plt.ylabel('Density')
plt.title('std_dev = {}; kurtosis = {};\nskew = {}; \nmean = {}; median = {}'.format((round(cal_fun(dat, num_var[3])[2][0],2),round(cal_fun(dat, num_var[3])[2][1],2)),
                                                                                                   round(cal_fun(dat, num_var[3])[4],2),
                                                                                                   round(cal_fun(dat, num_var[3])[3],2),
                                                                                                
                                                                                                   round(cal_fun(dat, num_var[3])[0],2),
                                                                                                   round(cal_fun(dat, num_var[3])[1],2)))
plt.show()

# %% [markdown]
# * Median dropoff longitude = -73.98
#
# * Most dropoff longitude range form -74.04 to -73.9
#
# * Skewness -449.89 : very likely to be biased towards higher values of longititude
#
# * Kurtosis = 309924 ; very likely to have extreme/outlier values.

# %%
plt.figure(figsize = (7,3), dpi = 100)
sns.kdeplot(x=dat[num_var[4]],shade=True)
sns.scatterplot( cal_fun(dat, num_var[4])[0], [0], color='red', label='mean')
sns.scatterplot( cal_fun(dat, num_var[4])[1] , [0], color='green', label='median')
sns.lineplot( cal_fun(dat, num_var[4])[2], [0,0], color='black', label='standard deviation')
plt.xlabel(num_var[4])
plt.ylabel('Density')
plt.title('std_dev = {}; kurtosis = {};\nskew = {}; \nmean = {}; median = {}'.format((round(cal_fun(dat, num_var[4])[2][0],2),round(cal_fun(dat, num_var[4])[2][1],2)),
                                                                                                   round(cal_fun(dat, num_var[4])[4],2),
                                                                                                   round(cal_fun(dat, num_var[4])[3],2),
                                                                                                
                                                                                                   round(cal_fun(dat, num_var[4])[0],2),
                                                                                                   round(cal_fun(dat, num_var[4])[1],2)))
plt.show()

# %% [markdown]
# * Median dropoff latitude = 40.75
#
# * Most dropoff latitude range form 40.72 to 40.79
#
# * Skewness -23.5 : very likely to be baised towards higher values of latitude
#
# * Kurtosis = 5639.24 ; very likely to have extreme/outlier values.

# %%
plt.figure(figsize = (7,3), dpi = 100)
sns.kdeplot(x=dat[num_var[5]],shade=True)
sns.scatterplot( cal_fun(dat, num_var[5])[0], [0], color='red', label='mean')
sns.scatterplot( cal_fun(dat, num_var[5])[1] , [0], color='green', label='median')
sns.lineplot( cal_fun(dat, num_var[5])[2], [0,0], color='black', label='standard deviation')
plt.xlabel(num_var[5])
plt.ylabel('Density')
plt.title('std_dev = {}; kurtosis = {};\nskew = {}; \nmean = {}; median = {}'.format((round(cal_fun(dat, num_var[5])[2][0],2),round(cal_fun(dat, num_var[5])[2][1],2)),
                                                                                                   round(cal_fun(dat, num_var[5])[4],2),
                                                                                                   round(cal_fun(dat, num_var[5])[3],2),
                                                                                                
                                                                                                   round(cal_fun(dat, num_var[5])[0],2),
                                                                                                   round(cal_fun(dat, num_var[5])[1],2)))
plt.show()

# %% [markdown]
# * Median trip duration = 663
#
# * Most trip duration range form -29124 to 4816.86
#
# * Skewness 186.68 : very likely to be baised towards low values of duration
#
# * Kurtosis = 87142.46 ; very likely to have extreme/outlier values.

# %%
#Check missing values 
dat.isnull().sum()
# Out:
# id                    0
# vendor_id             0
# pickup_datetime       0
# dropoff_datetime      0
# passenger_count       0
# pickup_longitude      0
# pickup_latitude       0
# dropoff_longitude     0
# dropoff_latitude      0
# store_and_fwd_flag    0
# trip_duration         0
# dtype: int64

# %%
dat['store_and_fwd_flag'].value_counts()
# Out:
# N    725282
# Y      4040
# Name: store_and_fwd_flag, dtype: int64

# %%
#Univariate analysis categorical variable 
norm_count = dat['store_and_fwd_flag'].value_counts(normalize = True)
n_uni = dat['store_and_fwd_flag'].nunique()

sns.barplot(norm_count, norm_count.index , order = norm_count.index)
plt.xlabel('fraction/percent', fontsize = 20)
plt.ylabel('store_and_fwd_flag', fontsize = 20)
plt.title('n_uniques = {} \n value counts \n {};'.format(n_uni,norm_count))
# Out:
# Text(0.5, 1.0, 'n_uniques = 2 \n value counts \n N    0.994461\nY    0.005539\nName: store_and_fwd_flag, dtype: float64;')

# %% [markdown]
# * Majority of trips are not store and forwarded trips

# %%
#Univariate analysis categorical variable 
norm_count1 = dat['vendor_id'].value_counts(normalize = True)
n_uni1 = dat['vendor_id'].nunique()
sns.barplot(norm_count1, norm_count1.index ,orient='h')
#sns.barplot(norm_count1, norm_count1.index , order = norm_count1.index)
plt.xlabel('fraction/percent', fontsize = 20)
plt.ylabel('vendir_id', fontsize = 20)
plt.title('n_uniques = {} \n value counts \n {};'.format(n_uni1,norm_count1))
# Out:
# Text(0.5, 1.0, 'n_uniques = 2 \n value counts \n 2    0.535403\n1    0.464597\nName: vendor_id, dtype: float64;')

# %% [markdown]
# * The difference in vendor_id codes is about 8%

# %%
#Checking outliers  
# custom function for easy outlier analysis

def UVA_outlier(data, var_group, include_outlier = True):
  '''
  Univariate_Analysis_outlier:
  takes a group of variables (INTEGER and FLOAT) and plot/print boplot and descriptives\n
  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it \n\n

  data : dataframe from which to plot from\n
  var_group : {list} type Group of Continuous variables\n
  include_outlier : {bool} whether to include outliers or not, default = True\n
  '''

  size = len(var_group)
  plt.figure(figsize = (7*size,4), dpi = 100)
  
  #looping for each variable
  for j,i in enumerate(var_group):
    
    # calculating descriptives of variable
    quant25 = data[i].quantile(0.25)
    quant75 = data[i].quantile(0.75)
    IQR = quant75 - quant25
    med = data[i].median()
    whis_low = med-(1.5*IQR)
    whis_high = med+(1.5*IQR)

    # Calculating Number of Outliers
    outlier_high = len(data[i][data[i]>whis_high])
    outlier_low = len(data[i][data[i]<whis_low])

    if include_outlier == True:
      print(include_outlier)
      #Plotting the variable with every information
      plt.subplot(1,size,j+1)
      sns.boxplot(data[i], orient="v")
      plt.ylabel('{}'.format(i))
      plt.title('With Outliers\nIQR = {}; Median = {} \n 2nd,3rd  quartile = {};\n Outlier (low/high) = {} \n'.format(
                                                                                                   round(IQR,2),
                                                                                                   round(med,2),
                                                                                                   (round(quant25,2),round(quant75,2)),
                                                                                                   (outlier_low,outlier_high)
                                                                                                   ))
      
    else:
      # replacing outliers with max/min whisker
      data2 = data[var_group][:]
      data2[i][data2[i]>whis_high] = whis_high+1
      data2[i][data2[i]<whis_low] = whis_low-1
      
      # plotting without outliers
      plt.subplot(1,size,j+1)
      sns.boxplot(data2[i], orient="v")
      plt.ylabel('{}'.format(i))
      plt.title('Without Outliers\nIQR = {}; Median = {} \n 2nd,3rd  quartile = {};\n Outlier (low/high) = {} \n'.format(
                                                                                                   round(IQR,2),
                                                                                                   round(med,2),
                                                                                                   (round(quant25,2),round(quant75,2)),
                                                                                                   (outlier_low,outlier_high)
                                                                                                   ))

# %%
UVA_outlier(dat, num_var[0:3],)
# Out:
# True
# True
# True

# %%
UVA_outlier(dat, num_var[3:],)
# Out:
# True
# True
# True

# %% [markdown]
# Outliers are significant in number

# %%
#Bivaritate Analysis 
#Cont-Cont 
sns.pairplot(dat[num_var])

# %% [markdown]
# * Most of scatter plots are  not meaningful due to the presence of outliers
# * Obvious Correlation between dropoff_latitiude and pickup latittude

# %%
#Vendor_id categories
dat['vendor_id'].value_counts()
# Out:
# 2    390481
# 1    338841
# Name: vendor_id, dtype: int64

# %%
def TwoSampT(X1, X2, sd1, sd2, n1, n2):
  '''
  takes mean, standard deviation, and number of observations and returns p-value calculated for 2-sample T-Test
  '''
  from numpy import sqrt, abs, round
  from scipy.stats import t as t_dist
  ovr_sd = sqrt(sd1**2/n1 + sd2**2/n2)
  t = (X1 - X2)/ovr_sd
  df = n1+n2-2
  pval = 2*(1 - t_dist.cdf(abs(t),df))
  return pval

# %%
#calculating p-values
t_p_val = TwoSampT(m1, m2, std1, std2, n1, n2)

# %%
def TwoSampZ(X1, X2, sigma1, sigma2, N1, N2):
  '''
  takes mean, standard deviation, and number of observations and returns p-value calculated for 2-sampled Z-Test
  '''
  from numpy import sqrt, abs, round
  from scipy.stats import norm
  ovr_sigma = sqrt(sigma1**2/N1 + sigma2**2/N2)
  z = (X1 - X2)/ovr_sigma
  pval = 2*(1 - norm.cdf(abs(z)))
  return pval

# %%
#Bivaritate Analysis 
#Cont-Cat 
def Bivariate_cont_cat(data, cont, cat, category):
  #creating 2 samples
  x1 = data[cont][data[cat]==category][:]
  x2 = data[cont][~(data[cat]==category)][:]
  
  #calculating descriptives
  n1, n2 = x1.shape[0], x2.shape[0]
  m1, m2 = x1.mean(), x2.mean()
  std1, std2 = x1.std(), x2.mean()
  
  #calculating p-values
  t_p_val = TwoSampT(m1, m2, std1, std2, n1, n2)
  z_p_val = TwoSampZ(m1, m2, std1, std2, n1, n2)

  #table
  table = pd.pivot_table(data=data, values=cont, columns=cat, aggfunc = np.mean)

  #plotting
  plt.figure(figsize = (15,6), dpi=140)
  
  #barplot
  plt.subplot(1,2,1)
  sns.barplot([str(category),'not {}'.format(category)], [m1, m2])
  plt.ylabel('mean {}'.format(cont))
  plt.xlabel(cat)
  plt.title('t-test p-value = {} \n z-test p-value = {}\n {}'.format(t_p_val,
                                                                z_p_val,
                                                                table))

  # boxplot
  plt.subplot(1,2,2)
  sns.boxplot(x=cat, y=cont, data=data)
  plt.title('categorical boxplot')

# %%
##'passenger_count' Vs 'store_and_fwd_flag'
Bivariate_cont_cat(dat, num_var[0], cat_var[0], 'N')

# %% [markdown]
# Inferences
#
# passsenger count is higher for sotred trips  , and the results are significantly different
#
# Boxplot shows outliers for both categories
#
# Result
#
# We can safely retain the hypothesis that passenger count and store_and_fwd_flag are soemhow related

# %%
##'pickup_longitude' Vs 'store_and_fwd_flag'
Bivariate_cont_cat(dat, num_var[1], cat_var[0], 'N')

# %% [markdown]
# Inferences
#
# pick up longitude is almost the same for stored and not stored forwarded trips , but the results are not significantly different
#
# Boxplot shows outliers on both end but more outliers for not store trips.
#
# Result
#
# We can safely reject the hypothesis that drop off longitude and store_and_fwd_flag are are soemhow related

# %%
##'pickup_latitude' Vs 'store_and_fwd_flag'
Bivariate_cont_cat(dat, num_var[2], cat_var[0], 'N')

# %% [markdown]
# Inferences
#
# pick up latitude is almost the same for stored and not stored forwarded trips , but the results are not significantly different
#
# Boxplot shows outliers on both end but more outliers for not store trips.
#
# Result
#
# We can safely reject the hypothesis that drop off longitude and store_and_fwd_flag are are soemhow related

# %%
## 'dropoff_longitude' Vs 'store_and_fwd_flag'
Bivariate_cont_cat(dat, num_var[3], cat_var[0], 'N')

# %% [markdown]
# Inferences
#
# drop off longitude is almost the same for stored and not stored forwarded trips , but the results are not significantly different
#
# Boxplot shows outliers on both end but more outliers frr not store trips.
#
# Result
#
# We can safely reject the hypothesis that drop off longitude and store_and_fwd_flag are are soemhow related

# %%
## 'dropoff_latitude' Vs 'store_and_fwd_flag'
Bivariate_cont_cat(dat, num_var[4], cat_var[0], 'N')

# %% [markdown]
# Inferences
#
# drop off latitude is almost the same for stored and not stored forwarded trips , but the results are  not significantly different
#
# Boxplot shows outliers on both end but more outliers for not store trips.
#
# Result
#
# We can safely reject  the hypothesis that drop off latitude and store_and_fwd_flag are are soemhow related

# %%
## 'trip_duration' Vs 'store_and_fwd_flag'
Bivariate_cont_cat(dat, num_var[5], cat_var[0], 'N')

# %% [markdown]
# Inferences
#
# trip duration is higher for sotred and not sotre forwarded trips , and the results are significantly different
#
# Boxplot shows outliers for both categories
#
# Result
#
# We can safely retain the hypothesis that pick up latitude and store_and_fwd_flag are soemhow related

# %%
###'passenger_count' Vs 'vendor_id'
Bivariate_cont_cat(dat, num_var[0], cat_var[1], 1)

# %% [markdown]
# Inferences
#
# passenger count is higher  for vendor id 1 and not 1  , and  the results are significantly different
#
# Boxplot shows more outliers for store and forwarded trips
#
# Result
#
# We can safely retain the hypothesis that passenger count and vendor id are soemhow related

# %%
##'pickup_longitude' Vs 'vendor_id'
Bivariate_cont_cat(dat, num_var[1], cat_var[1], 1)

# %% [markdown]
# Inferences
#
# pick up longitude is almost the same for vendor id 1 and not 1 , but the results are not significantly different
#
# Boxplot shows outliers on both end.
#
# Result
#
# We can safely reject the hypothesis that pick up logititude and vendor id are soemhow related

# %%
#pickup_latitude' Vs 'vendor_id'
Bivariate_cont_cat(dat, num_var[2], cat_var[1], 1)

# %% [markdown]
# Inferences
#
# pick up latitude is almost the same for vendor id 1 and not 1 , but the results are not significantly different
#
# Boxplot shows outliers on both end.
#
# Result
#
# We can safely reject the hypothesis that pick up latitude and vendor id are soemhow related

# %%
#'dropoff_longitude' Vs 'vendor_id'
Bivariate_cont_cat(dat, num_var[3], cat_var[1], 1)

# %% [markdown]
# Inferences
#
# drop off longitude is almost the same for vendor id 1 and not 1  , but the results are  not significantly different
#
# Boxplot shows outliers on both end.
#
# Result
#
# We can safely reject  the hypothesis that drop off longitude  and vendor id are soemhow related

# %%
#'dropoff_latitude' Vs 'vendor_id'
Bivariate_cont_cat(dat, num_var[4], cat_var[1], 1)

# %% [markdown]
# Inferences
#
# drop off latitude is almost the same for   vendor id = 1 and Not 1 , but the results are  not significantly different
#
# Boxplot shows outliers on both end.
#
# Result
#
# We can safely reject  the hypothesis that drop off latitude and vendor id are soemhow related

# %%
#'trip_duration' vs 'vendor_id'
Bivariate_cont_cat(dat, num_var[5], cat_var[1], 1)

# %% [markdown]
# Inferences
#
# trip duration is higher for  vendor id = 1, and the results are  significantly different
#
# Boxplot shows outliers on the higher end.
#
# Result
#
# We can safely retain the hypothesis that trip duration and vendor id ar soemhow related

# %% [markdown]
# ## Observations Summary
# #### From the EDA we performed in the previous assignment we have the following observations:
#  0. id can be removed from dataset because it does not contribute to
#  1. 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude', 'trip_duration' are highly skewed
#  2. The same variables have extreme outliers that should be removed
#  3. We propose to normlaize data
#  4. Remove highly corellated variables
#  5. Cretae new features duration the idfference between start trip and end trip
